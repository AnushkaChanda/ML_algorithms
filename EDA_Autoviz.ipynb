# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushkaChanda/ML_algorithms/blob/main/EDA_Autoviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.to_csv('tips.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV= AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = "sample_data/california_housing_train.csv"

dft = AV.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (17000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_65c25_row0_col0, #T_65c25_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_65c25_row0_col1, #T_65c25_row0_col6, #T_65c25_row1_col1, #T_65c25_row1_col6, #T_65c25_row2_col1, #T_65c25_row2_col6, #T_65c25_row3_col1, #T_65c25_row3_col6, #T_65c25_row4_col1, #T_65c25_row4_col6, #T_65c25_row5_col1, #T_65c25_row5_col6, #T_65c25_row6_col1, #T_65c25_row6_col6, #T_65c25_row7_col1, #T_65c25_row7_col6, #T_65c25_row8_col1, #T_65c25_row8_col6 {
#   font-family: Segoe UI;
# }
# ...
